# %% [markdown]
# ## 클래스 변수와 인스턴스 변수

# %%
class Car:
    # 클래스 변수의 위치
    max_speed = 300
    max_people = 5
    car_gear = ['P', 'D', 'R', 'N']

modelx = Car()
modely = Car()

modely.max_speed = 500  # 인스턴스 변수를 변경 (클래스 변수 X)

print(id(Car.max_speed))    #300
print(id(modelx.max_speed)) #300
print(id(modely.max_speed)) #500(인스턴스 변수를 출력)
# Out:
# 133673117816688
# 133673117816688
# 133673117812560

# %%
class Car:
    kinds = []
    speed = 300

    def add_kinds(self, name):  #kinds 라는 list가 변수에 없음으로 class변수로 들어감
        self.kinds.append(name)

    def change_speed(self, speed): #인스턴스 변수
        self.speed = speed

modelx = Car()
modely = Car()

modelx.add_kinds('x')
modely.add_kinds('y')

Car.speed = 100

modelx.change_speed(500)
modely.change_speed(250)

print(f'modelx.kinds: {modelx.kinds}') #add_kinds안에 kind라는 list가 없음으로 class의 변수를 가져옴
print(f'modely.kinds: {modely.kinds}')
print(f'modelx.speed: {modelx.speed}')
print(f'modely.speed: {modely.speed}')
# Out:
# modelx.kinds: ['x', 'y']
# modely.kinds: ['x', 'y']
# modelx.speed: 500
# modely.speed: 250

# %%
x = 100
def testx():
    x = 200

testx()
x #지역변수 x
# Out:
# 100

# %%
x = 100
def testx():
    global x #전역변수 x
    x += 100

testx()
x
# Out:
# 200

# %%
l = [1, 2, 3]

def addlist(ll):
    ll.append(40)

addlist(l)
l
# Out:
# [1, 2, 3, 40]

# %%
class Counter:

    def __init__(self):
        self.num = 0

    def __len__(self):
        return 100

    def __call__(self):
        return 'hello'

    def __getitem__(self, key):
        return key*10

c = Counter()
len(c)
c()
c[10]
# Out:
# 100

# %%
#클래스의 상속

class A(object):
    test = 0
    def one(self):
        return 'one'

class B(A):
    def two(self):
        return 'two'

class C(B):
    def three(self):
        return 'three'

c = C()


c.three()
A.test = 300
c.test #상속을 받을 때 내 메모리 영역의 값(보유하고 있는 값)은 아닙니다! 참조값 입니다.
# Out:
# 300

# %%
class Car(object):
    maxSpeed = 300
    maxPeople = 5

    def move(self):
        print('차가 출발합니다~')

    def srop(self):
        print('차가 정지합니다~')

class HybridCar(Car):
    battery = 1000
    batteryKM = 300

class ElectricCar(HybridCar):
    battery = 2000
    batteyKM = 600

modelx = HybridCar()
electriCarModely = ElectricCar()

print(modelx.maxSpeed)
print(electriCarModely.maxSpeed)
print(modelx.battery)
print(electriCarModely.battery)
print(electriCarModely.move())  # + None 머지?
# Out:
# 300
# 300
# 1000
# 2000
# 차가 출발합니다~
# None

# %% [markdown]
# ## 다중상속

# %%
#다중상속

class A:
    def hello(self):
        print('hello A')

class B:
    def hello(self):
        print('hello B')

class C(A, B):
    pass

c = C()
c.hello() #주의! python의 코드의 특성상 hello B라고 오해할만 합니다. 2.x, 3.x 상속순서가 다릅니다.
# Out:
# hello A

# %%
#주의! python의 코드의 특성상 hello B라고 오해할만 합니다. 2.x, 3.x 상속순서가 다릅니다.

class A:
    def hello(self):
        print('hello A')

class B(A):
    def hello(self):
        print('hello B')

class C(A):
    def hello(self):
        print('hello C')

#다이아몬드 상속
class D(B, C):
        pass

c = C()
c.hello()

d = D()
d.hello()
print(D.mro()) #Class D B C A object
# Out:
# hello C
# hello B
# [<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>]

# %%
#다중상속에서 에러가 발생하는 경우
#상속 순서에 맞지않게 불러 들렸을 때 예시

class A:
    def hello(self):
        print('hello A')

class B(A):
    def hello(self):
        print('hello B')

class C(B):
    def hello(self):
        print('hello C')

#다이아몬드 상속
class D(B, C):
        pass

d = D()
d.hello()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-174136f0f312> in <cell line: 17>()
#      15
#      16 #다이아몬드 상속
# ---> 17 class D(B, C):
#      18         pass
#      19
#
# TypeError: Cannot create a consistent method resolution
# order (MRO) for bases B, C

# %% [markdown]
# ## 연습문제

# %% [markdown]
# 게임에서 캐릭터를 구현하려고 한다. 아래 클래스를 적절하게 조합하여 hero인스턴스와 villain 인스턴스를 만들어주세요.
#
# 1. class Body (능력치)
# 2. class Weapon (무기)
# 3. class Weapon Enhancement (무기강화)
# 4. class Skill (기술)
# 5. class Equipment (장비)
# 6. class Role (히어로인지, 빌런인지, 몹인지)

# %%
#각각의 클래스를 만들고
#마지막 클래스 히어로, 빌런 클레스 에다가 다 때려박기

class Body:

    def __init__(self, stn, dex, luk, inte):
        self.stn = stn
        self.dex = dex
        self.luk = luk
        self.inte = inte

class Weapon:

    def __init__(self, weapon):
        self.weapon = weapon

class WeaponEnhancement:

    def __init__(self, weaponenchant):
        self.weaponchant = weaponenchant

class Skill:
    skills = []
    def addSkill(self, skillname):
        if skills != []:
            self.skills.append(skillname)
        else:
            self.skills.append(skillname)

class Equipment:

    def myquipment(self):
        pass

class Role:

    def __init__(self, role):
        self.role = role

# %%
class hero(Body, Weapon, WeaponEnhancement, Skill, Equipment, Role):
    def __init__(self, stn, dex, luk, inte, weapon, weaponenchant, role):
        Body.__init__(self, stn, dex, luk, inte)
        Weapon.__init__(self, weapon)
        WeaponEnhancement.__init__(self, weaponenchant)
        Skill.__init__(self)
        Equipment.__init__(self)
        Role.__init__(self, role)
        self.skills = []

용사1 = hero(10, 20, 20, 5, '용사의검', '강화', '전사')

#별로인것 같다... 수정 하기 어렵고 가독성이 떨어지는 코드
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-72beb565d5d4> in <cell line: 12>()
#      10
#      11 용사1 = hero(10, 20, 20, 5, '용사의검', '강화', '전사')
# ---> 12 용사1.addSkill('베기')
#      13
#      14 #별로인것 같다...
#
# <ipython-input-57-a220fa766174> in addSkill(self, skillname)
#      23     skills = []
#      24     def addSkill(self, skillname):
# ---> 25         if skills != []:
#      26             self.skills.append(skillname)
#      27         else:
#
# NameError: name 'skills' is not defined

# %%
#기본틀
class Weapon:
    pass
class WeaponEnhancement(Weapon):
    pass
class Equipment(WeaponEnhancement):
    pass

class Role:
     def setRole(self, role):
        self.role = role

class Skill:
    def slash(self):
        return '베기!'

class Body(Role, Skill, Equipment):
    def __init__(self, role, hp, mp, power):
        self.setRole(role)

hero = Body('hero', 100, 50, 50)
hero.slash()
# Out:
# '베기!'

# %%
class Weapon:

    def setWeapon(self, weapon):
        self.weapon = weapon

    def setDamage(self, damage):
        self.damage = damage

class WeaponEnhancement(Weapon):
    def setEnhancement(self):
        import random
        percent = random.randint(1, 100)
        if percent >= 50:
            self.damage *= 2
            self.log = '성공'
            return '강화성공!'
        else:
            if self.damage <= 100:
                self.damage = 100
            self.damage /= 2
            self.log = '실패'
            return '강화실패!'
class Equipment(WeaponEnhancement):

    def setquipment(self, helmet =' ', top = '', bottom = '', earring = ''):
        self.helmet = helmet
        self.top = top
        self.bottom = bottom
        self.earring = earring

class Role:
     def setRole(self, role):
        self.role = role

class Skill:
    def slash(self):
        return '베기!'
    def beam(self):
        return '빔!!'

class Body(Role, Skill, Equipment):
    def __init__(self, role, hp, mp, power, weapon):
        self.setRole(role)
        self.hp = hp
        self.mp = mp
        self.power = power
        self.setWeapon(weapon)

hero = Body('hero', 100, 50, 50, '용사의 검')
hero.setquipment('가죽헬멧', '속옷', '', '귀걸이')
print(hero.beam())
print(hero.earring)
# Out:
# 빔!!
# 귀걸이

# %%
#데미지 초기화
hero.damage = 1

# %%
count = 1
myscore = []
mylog = []
while True:
    if hero.damage >= 100000:
        break
    print(hero.setEnhancement(), f'{count}번째 시도입니다.')
    count += 1
    print(hero.damage)
    myscore.append(int(hero.damage))
    mylog.append(hero.log)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 1.0
# 강화성공! 1192317번째 시도입니다.
# 2.0
# 강화실패! 1192318번째 시도입니다.
# 1.0
# 강화실패! 1192319번째 시도입니다.
# 1.0
# 강화실패! 1192320번째 시도입니다.
# 1.0
# 강화실패! 1192321번째 시도입니다.
# 1.0
# 강화성공! 1192322번째 시도입니다.
# 2.0
# 강화실패! 1192323번째 시도입니다.
# 1.0
# 강화실패! 1192324번째 시도입니다.
# 1.0
# 강화실패! 1192325번째 시도입니다.
# 1.0
# 강화성공! 1192326번째 시도입니다.
# 2.0
# 강화성공! 1192327번째 시도입니다.
# 4.0
# 강화실패! 1192328번째 시도입니다.
# 2.0
# 강화실패! 1192329번째 시도입니다.
# 1.0
# 강화실패! 1192330번째 시도입니다.
# 1.0
# 강화실패! 1192331번째 시도입니다.
# 1.0
# 강화성공! 1192332번째 시도입니다.
# 2.0
# 강화성공! 1192333번째 시도입니다.
# 4.0
# 강화실패! 1192334번째 시도입니다.
# 2.0
# 강화성공! 1192335번째 시도입니다.
# 4.0
# 강화성공! 1192336번째 시도입니다.
# 8.0
# 강화성공! 1192337번째 시도입니다.
# 16.0
# 강화실패! 1192338번째 시도입니다.
# 8.0
# 강화실패! 1192339번째 시도입니다.
# 4.0
# 강화실패! 1192340번째 시도입니다.
# 2.0
# 강화성공! 1192341번째 시도입니다.
# 4.0
# 강화실패! 1192342번째 시도입니다.
# 2.0
# 강화실패! 1192343번째 시도입니다.
# 1.0
# 강화실패! 1192344번째 시도입니다.
# 1.0
# 강화실패! 1192345번째 시도입니다.
# 1.0
# 강화실패! 1192346번째 시도입니다.
# 1.0
# 강화실패! 1192347번째 시도입니다.
# ...

# %%
from collections import Counter
print(sorted(myscore, reverse = True)[:10])
print(Counter(mylog))
rate = Counter(mylog)
countrate = rate['성공'] / (rate['성공'] + rate['실패'])
countrate
# Out:
# [512, 512, 256, 256, 256, 256, 256, 256, 256, 256]
# Counter({'실패': 944521, '성공': 250294})
# 0.20948347652146984

# %% [markdown]
# ## 클래스 메서드와 정적 메서드

# %%
#클래스 메서드
#클래스 안에있는 값을 조정
class Myclass:
    count = 0

    @classmethod
    def increment(cls):
        cls.count += 1

a = Myclass()
b = Myclass()

Myclass.increment()
Myclass.increment()
print(Myclass.count)
a.count, b.count
# Out:
# 2
# (2, 2)

# %%
# 클래스 메서드
class MyClass:
    count = 0

    def increment(self):
        self.count += 1

a = MyClass()
b = MyClass()

# MyClass.increment() # error
a.increment()

print(a.count, b.count)

a.increment()

print(a.count, b.count)
# Out:
# 1 0
# 2 0

# %%
#정적 메서드

class MyClass:
    count = 10  #별개의 카운트
    @staticmethod
    def my_method(x, y):
        count = 0 #별개의 카운트 읽는 것 접근 안됩니다.
        return x + y + count

print(MyClass.my_method(5, 3))  # 출력: 8
# Out:
# 8

# %%
class 학사정보시스템:
    학점총점 = 120

    def __init__(self):
        self.학기점수 = []

    def 학점추가(self, 이번학기점수):
        self.학기점수.append(이번학기점수)

    def 학점평균 (self):
        return round(sum(self.학기점수) / len(self.학기점수), 2)

    def 졸업장출력(self):
        return f'총 학점 {self.학점총점}학점, 평균 {self.학점평균()}학점으로 졸업하셨습니다.'

    @staticmethod
    def 학사경고(이번학기점수):
        if 이번학기점수 - 1.5 > 0:
            return '학사경고 아님'
        return '학사경고!!!'


    @classmethod #클래스 매서드 사용
    def 학점총점변경(cls, 총점):
        if isinstance(총점, int):
            cls.학점총점 = 총점
            return '변경됨'
        return '이상해. 변경안됨'

a = 학사정보시스템()
b = 학사정보시스템()
a.학점추가(4.5)
a.학점추가(4)
a.학점추가(3.58)
a.학점추가(3.58)
a.학점추가(4)
a.학점추가(3)
a.학점추가(2.8)
a.학점추가(3.4)
b.학점추가(4.5)
b.학점추가(4)
b.학점추가(3.58)
b.학점추가(3.58)
b.학점추가(4)
b.학점추가(3)
b.학점추가(2.8)
b.학점추가(3.4)
print(a.학점평균())
print(a.졸업장출력())
# Out:
# 3.61
# 총 학점 120학점, 평균 3.61학점으로 졸업하셨습니다.

# %%
## 총학점 변경

학사정보시스템.학점총점 = 60
학사정보시스템.학점총점 = '60' #위험한 상황, 숫자가 들어가야 하는데 문자가 들어감

print(a.졸업장출력())
print(b.졸업장출력())  #둘 다 총학점 변경
# Out:
# 총 학점 60학점, 평균 3.61학점으로 졸업하셨습니다.
# 총 학점 60학점, 평균 3.61학점으로 졸업하셨습니다.

# %%
학사정보시스템.학점총점변경(90)
학사정보시스템.학사경고(1)
# Out:
# '학사경고!!!'

# %% [markdown]
# ## 속성 접근자와 덕타이핑

# %%
# property
class Person:
    def __init__(self, first_name, last_name):
        self.first_name = first_name
        self.last_name = last_name

    @property
    def full_name(self):
        return f'{self.first_name}{self.last_name}' #클래스 내부에서 self.full_name인스턴스 변수처럼 취급

man = Person('kim', 'changhwan')
licat = Person('li', 'cat')

print(man.full_name)
print(man.first_name)
# Out:
# kimchanghwan
# kim

# %%
#덕 타이핑
# 예제에서 introduce(obj) 에서 클래스에 따라 나오는 내용이 다름
#가독성 측면, 짧게 duck의 object를 들여다보지 않고 어느정도 기능을 유추할 수 있게됨
#여러가지 obj를 하나의 함수에서 실행하며 커스터마이징 가능
class Duck:
    def introduce(self):
        print('꽥꽥!')

class Person:
    def introduce(self):
        print('안녕하세요!')

def sayhi(obj):
    print('인사시작')
    obj.introduce()

duck = Duck()
person = Person()

sayhi(person)
sayhi(duck)
# Out:
# 인사시작
# 안녕하세요!
# 인사시작
# 꽥꽥!

# %%
class Person:
    def move(self):
        print('움직임')

class Hero(Person):
    def move(self):
        print('히어로 움직임')

class Villain:
    def move(self):
        print('빌런 움직임')

class Mob:
    def move(self):
        print('몹 움직임')

def move(obj):
    obj.move()

a = Hero()
b = Villain()
c = Mob()

등장인물 = [a, b, c]

for person in 등장인물:
    person.move()
    move(person)
# Out:
# 히어로 움직임
# 히어로 움직임
# 빌런 움직임
# 빌런 움직임
# 몹 움직임
# 몹 움직임

# %% [markdown]
# ## 추상 클래스

# %%
#추상클래스

from abc import ABC, abstractmethod

class Person(ABC): #ABC를 상속받고

    @abstractmethod  #abstractmethod라고 선언을 하면
    def move(self):
        print('move')

    @abstractmethod
    def 밥먹기(self):
        pass

class Hero(Person): #상속받은 자식에서 '반드시' 메서드 오버라이딩이 일어나야 합니다.

    def 날기(self):
        pass

ironman = Hero()
ironman.move()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-51dea05da16c> in <cell line: 18>()
#      16     pass
#      17
# ---> 18 ironman = Hero()
#      19 ironman.move()
#
# TypeError: Can't instantiate abstract class Hero with abstract methods move, 밥먹기

# %%
#추상클래스

from abc import ABC, abstractmethod

class Person(ABC): #ABC를 상속받고

    @abstractmethod  #abstractmethod라고 선언을 하면
    def move(self):
        pass

    @abstractmethod
    def 밥먹기(self):
        pass

class Hero(Person): #상속받은 자식에서 '반드시' 메서드 오버라이딩이 일어나야 합니다.
#move, 밥먹기 둘 다 오버라이드 하지 않으면 오류 발생
#명시적으로 얘를 상속받는 클래스들은 이런식으로 틀을 짜겠다고 협업할 때 표시.
    def move(self):
        print('얘는 날아다녀요.')

    def 밥먹기(self):
        print('얘는 밥도 안먹어요.')

ironman = Hero()
ironman.move()
ironman.밥먹기()
# Out:
# 얘는 날아다녀요.
# 얘는 밥도 안먹어요.

# %% [markdown]
# ## 비공개 속성

# %% [markdown]
# 비공개 속성(Private Attributes)은 클래스 내부에서만 접근이 가능하며
# 외부에서는 접근이 제한되는 속성을 의미합니다.
# 파이썬에서는 속성 이름 앞에 두 개의 언더스코어(`__`)를 붙여 해당 속성을 비공개처럼 표현할 수 있습니다.

# %%
# 비공개 속성이 조작 불가능한게 아닙니다!
class MyClass:
    __a = 10
    _a = 100
    b = 20

    def __init__(self, c, d):
        self.__c = c
        self.d = d

# MyClass.__a
test = MyClass(30, 40)
print(test._MyClass__a) #조회 할 수 있음.
print(test._MyClass__c)
# Out:
# 10
# 30

# %% [markdown]
# ## 모듈과 패키지

# %%
#모듈
#jun.py작성후 불러와서 사용하기

import jun

jun.hello #jun.py의 함수
jun.name #jun.py의 변수
# Out:
# 'changhwan'

# %%
from jun import name, age #이것도 많이 사용합니다. 그러나 개인적으로 사용하지 않는걸 추천
from jun2 import name, age



print(name)  #여기에 이름은 누구인가요
print(age)   #여기에 나이는 누구죠?
# Out:
# jun222
# 22

# %%
from jun import name as n
import jun as j
print(j.name)
# print(j.n)  error
# Out:
# changhwan

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import a #폴더가 있기 때문에 에러가 안납니다.
print(a)
# print(a, b, c) #error
# Out:
# <module 'a' (<_frozen_importlib_external._NamespaceLoader object at 0x7a39163b7a00>)>

# %%
# import a.b.c.hello #현재 폴더 나타낼 때에는 앞에 점을 개 붙입니다.
import a.b.c.hello as cat

print(hello)
print(a.b.c.hello.name)
print(cat.name)
print(a.b.c.hello.age)
print(cat.age)
# Out:
# <module 'a.b.c.hello' from '/content/a/b/c/hello.py'>
# licat
# licat
# 3
# 3

# %%
from a.b.c import hello as cat

print(hello.name)
print(cat.name)
# Out:
# licat
# licat

# %%
# !pip list #모듈 리스트 조회

# %% [markdown]
# ## 연습문제

# %%
#패키지 = 여러 모듈을 묶은 집합
#아래와 같은 기능을 하는 모듈 또는 패키지를 만들어 주세요
# 파일 또는 폴더로 만드셔야 합니다!
# add(a, b), sub(a, b), mul(a, b), div(a, b)
# _and(a, b), _or(a, b) # 다 하신 분 중 시간이 조금 남으신 분은 요것도 해보세요. :)

# %%
from a.b.c import addsome

print(addsome.add(5, 3))
print(addsome.sub(5, 3))
print(addsome.mul(5, 3))
addsome.div(56789, 48)
# Out:
# 5 + 3 = 8
# 5 - 3 = 2
# 5 X 3 = 15
# '56789 / 48 = 1183.104'

# %% [markdown]
# ## 자주 사용하는 모듈

# %%
# 450,000개 이상의 Python 패키지, 45만개의 바퀴
# PyPI(Python Package Index)
# https://pypi.org/search/?q=pandas&o=

# %%
import glob

print(glob.glob('/content/*.py'))
print(glob.glob('/*/*.py'))
print(glob.glob('????.py'))
# Out:
# ['/content/jun2.py', '/content/jun.py']
# ['/content/jun2.py', '/content/jun.py', '/python-apt/setup.py']
# ['jun2.py']

# %%
import sys

sys.path.append('/content/a/b/c')

# %%
#sys경로에 추가 한뒤에 import를 해주면 기본 경로에 추가해준다.
import addsome
'addsome' in sys.modules
# Out:
# True

# %%
#자주 사용하는 기본 모듈
import datetime

s = datetime.datetime(2303, 4, 8, 9, 5)
print(s.year)
print(s.month)
print(s.day)
print(s)
s.weekday() #월요일 0, 화요일1, 수요일2 ... 일요일6
# Out:
# 2303
# 4
# 8
# 2303-04-08 09:05:00
# 2

# %%
graduation_date = datetime.datetime(2023, 12, 29, 19, 00)
today = datetime.datetime.today()
days = datetime.timedelta(days = 100)
print(today + days)
graduation_date - today
# Out:
# 2023-12-28 05:24:01.732412
# datetime.timedelta(days=101, seconds=48958, microseconds=267588)

# %%
# /content 안의 파일찾기
import os
for curDir, dirs, files in os.walk('/content'):
    for f in files:
        print(os.path.join(curDir, f))
# Out:
# /content/jun2.py
# /content/jun.py
# /content/.config/.last_update_check.json
# /content/.config/default_configs.db
# /content/.config/.last_opt_in_prompt.yaml
# /content/.config/active_config
# /content/.config/config_sentinel
# /content/.config/gce
# /content/.config/.last_survey_prompt.yaml
# /content/.config/logs/2023.09.15/13.22.10.131489.log
# /content/.config/logs/2023.09.15/13.22.09.324179.log
# /content/.config/logs/2023.09.15/13.21.32.854551.log
# /content/.config/logs/2023.09.15/13.21.41.882195.log
# /content/.config/logs/2023.09.15/13.20.39.626976.log
# /content/.config/logs/2023.09.15/13.21.06.946322.log
# /content/.config/configurations/config_default
# /content/__pycache__/jun.cpython-310.pyc
# /content/__pycache__/jun2.cpython-310.pyc
# /content/a/b/c/addsome.py
# /content/a/b/c/hello.py
# /content/a/b/c/__pycache__/add.cpython-310.pyc
# /content/a/b/c/__pycache__/addsome.cpython-310.pyc
# /content/a/b/c/__pycache__/hello.cpython-310.pyc
# ...

# %%
import sys

a = [1, 2, 3]
b = a
c = a
sys.getrefcount(a)
# Out:
# 4

# %%
a = [1, 2, 3, 4]
print(sys.getrefcount(a))
print(sys.maxsize) #python 3.x에서는 거의 사용할 일이 없습니다.
# Out:
# 2
# 9223372036854775807

# %%
#json 형식

import json

d = {
    'one' : 1,
    'two' : 2,
    'three' : 3
}

jj = json.dumps(d)
dd = json.loads(jj)
# jj['one'] #error
dd['one']
# Out:
# 1

# %%
#class도 json.dumps() 를 통해 json string으로 변환하고 되돌릴 수 있을까?
import json
class Human:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    jun = Human(10, 20)
    json.dumps(jun)

# TypeError: Object of type Human is not JSON serializable(직렬화가 가능하지 않다!)
# 일반 인스턴스는 직렬화가 가능하지 않습니다!
# 직렬화: "데이터 구조나 오브젝트 상태를 동일하거나 다른 컴퓨터 환경에 저장
# (이를테면 파일이나 메모리 버퍼에서, 또는 네트워크 연결 링크 간 전송)하고,
# 나중에 재구성할 수 있는 포맷으로 변환하는 과정"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-3bfaf0e2c896> in <cell line: 2>()
#       1 #class도 json.dumps() 를 통해 json string으로 변환하고 되돌릴 수 있을까?
# ----> 2 class Human:
#       3     def __init__(self, x, y):
#       4         self.x = x
#       5         self.y = y
#
# <ipython-input-66-3bfaf0e2c896> in Human()
#       5         self.y = y
#       6
# ----> 7     jun = Human(10, 20)
#       8     json.dumps(jun)
#
# NameError: name 'Human' is not defined

# %%
#양방향 큐인 deque  코딩테스트에서 종종 사용됨.
import collections

d = collections.deque([1,2,3,4])
d.rotate(2) #default 오른쪽으로 회전
d
# Out:
# deque([3, 4, 1, 2])

# %%
c = collections.Counter('as111666411dfqwe6')
print(c)
print(c.most_common) # 많이나온 숫자대로 정렬
# Out:
# Counter({'1': 5, '6': 4, 'a': 1, 's': 1, '4': 1, 'd': 1, 'f': 1, 'q': 1, 'w': 1, 'e': 1})
# <bound method Counter.most_common of Counter({'1': 5, '6': 4, 'a': 1, 's': 1, '4': 1, 'd': 1, 'f': 1, 'q': 1, 'w': 1, 'e': 1})>

# %%
# 여러분은 이 코드만 가지고 있어주세요.
import requests
from bs4 import BeautifulSoup

paullab_url = 'http://paullab.co.kr/bookservice/'
response = requests.get(paullab_url)
response.encoding = 'utf-8'
html = response.text

soup = BeautifulSoup(html, 'html.parser')

bookservices = soup.select('.col-lg-6 > h2')     # col-lg-6 클래스 안의 h2 태그 탐색 #.this_text
for no, book in enumerate(bookservices, 1):
    print(no, book.text)
# Out:
# 1 메모혁신 Notion(노션) 활용 가이드
# 2 제주코딩베이스캠프 Code Festival: Python 100제 1부
# 3 튜토리얼로 배우는 HTML&CSS
# 4 코딩도장 튜토리얼로 배우는 Python 1편 object
# 5 코딩도장 튜토리얼로 배우는 python 2편 제어문
# 6 코딩도장 튜토리얼로 배우는 Python 문제풀이
# 7 타노스의 건틀릿 알고리즘 With Python
# 8 xlsxwriter 튜토리얼로 배우는 Python 엑셀 프로그래밍
# 9 러플 튜토리얼로 배우는 Python
# 10 인공지능을 활용한 업무자동화 With Google Developers Group JEJU
# 11 2017 제주 코딩 해커톤 Django 트랙 상편 1권

# %% [markdown]
# ## 예외처리

# %% [markdown]
# ### 주요 오류

# %%
# 문법 에러(Syntax Error)
if False:
    raise SyntaxError
if True:
    raise SyntaxError('하이용')
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-79-f4ee0cd35ad3>", line 4, in <cell line: 3>
#     raise SyntaxError('하이용')
#
#   File "<string>", line unknown
# SyntaxError: 하이용

# %%
# 이름 에러(Name Error)
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-deb2464f750f> in <cell line: 2>()
#       1 # 이름 에러(Name Error)
# ----> 2 print(x)
#
# NameError: name 'x' is not defined

# %%
#타입 에러(Type Error)
x = 10
y = '20'
print(x + y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-a6bbe58343d0> in <cell line: 4>()
#       2 x = 10
#       3 y = '20'
# ----> 4 print(x + y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#인덱스 에러(Index Error)
my_list = [1, 2, 3]
print(my_list[3]) #슬라이싱은 에러를 내지 않습니다. 많이 사용합니다.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-84-370b8179851f> in <cell line: 3>()
#       1 #인덱스 에러(Index Error)
#       2 my_list = [1, 2, 3]
# ----> 3 print(my_list[3]) #슬라이싱은 에러를 내지 않습니다. 많이 사용합니다.
#
# IndexError: list index out of range

# %%
#키 에러(Key Error)
my_dict = {'a': 1, 'b': 2}
print(my_dict['c'])

# %%
# 값에러 (Value Error)
int('a')
# ZeroDivision Error
x = 10
y = 0
print(x / y)

# %%
# 어트리뷰트 에러(Attribute Error)
# 객체에 존재하지 않는 속성이나 메소드를 호출했을 때 발생
my_list = [1, 2, 3]
print(my_list.appeend(4)) #appeend 오타로 인해 없는 메소드를 호출함

# %%
# 인자 개수 에러 Type Error
def add(x, y):
    return x + y

add(1, 2, 3) # *atgs, **kargs

# %%
# 인자 개수 에러 Type Error
def add(x, y, *args):
    print(x, y, *args)
    return x + y

add(1,2,3,4,5,6,7)
# Out:
# 1 2 3 4 5 6 7
# 3

# %%
# 파일 입출력 에러 File I/O Error
f = open('non-existent.txt', 'r')
f.read()

# %% [markdown]
# ### Python 예외처리

# %% [markdown]
# google convention에서는 try와 except를 최소 단위로 사용하길 권고합니다. 이는 애러가 나는 정확한 위치를 파악하기 위함입니다.

# %%
try:
    할인율: 0
    치킨값: 30000 / 할인율
    print('치킨주문 되었습니다.')
except:
    print('결제 안되었습니다.')
else:
    print('else')
# Out:
# 결제 안되었습니다.

# %%
try:
    할인율: 0
    # 치킨값: 30000 / 할인율
    print('치킨주문 되었습니다.')
except:
    print('결제 안되었습니다.')
else: #에러 없이 실행되면 else를 실행합니다. while, for + else 조합과 비슷합니다.
    print('else')
# Out:
# 치킨주문 되었습니다.
# else

# %%
#간단하게 에러만들고 테스트하기에 좋습니다.
test = 'hello'

assert test == 'hello', '애러 메시지 1' #1
assert test == 'world', '애러 메시지 2' #2
assert test + 3 == 5, '애러 메시지 3' #3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-c28bb990892a> in <cell line: 3>()
#       1 #간단하게 에러만들고 테스트하기에 좋습니다.
#       2 test = 'hello'
# ----> 3 raise('ㅋ')
#       4 assert test == 'hello', '애러 메시지 1' #1
#       5 assert test == 'world', '애러 메시지 2' #2
#
# TypeError: exceptions must derive from BaseException

# %%
x = 10
# raise
# raise ValueError
# raise ValueError('코드를 잘~~ 만들어주세요.')
y = 20

# %%
class myname(Exception): #Exception을 상속받으면 됩니다.
    def __init__(self):
        super().__init__('입력된 값이 leehojun이 아닙니다.')

raise myname
# Out:
# ---------------------------------------------------------------------------
# myname                                    Traceback (most recent call last)
# <ipython-input-94-1beb95d24b50> in <cell line: 5>()
#       3         super().__init__('입력된 값이 leehojun이 아닙니다.')
#       4
# ----> 5 raise myname
#
# myname: 입력된 값이 leehojun이 아닙니다.

# %%
import logging

logging.basicConfig(level=logging.INFO) # 어느 레벨부터 로깅할지, 기본으로 warning 부터 합니다.

logging.debug("This is a debug message") # 고쳐야 할 코드, 기록 필요
logging.info("This is an info message") # 정보성 메시지
logging.warning("This is a warning message") # 경고 메시지
logging.error("This is an error message") # 애러 메시지(프로그램은 동작)
logging.critical("This is a critical message") # 프로그램 중지(애러처리 안된경우)
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %%
import logging.handlers

def logger():
    log_obj = logging.getLogger("log_name") # log name으로 log 객체 생성
    log_obj.setLevel(logging.DEBUG) # 어디부터 기록할지 설정

    fileHandeler = logging.FileHandler(filename="./test.txt") # 파일로 기록
    # streamHandler = logging.StreamHandler() # 콘솔에 출력

    fileHandeler.setLevel(logging.INFO) # 파일 기록 레벨 설정
    # streamHandler.setLevel(logging.DEBUG) # 콘솔 기록 레벨 설정

    formatter = logging.Formatter("%(name)s, %(asctime)s, %(levelname)s, %(message)s") #포멧 생성

    fileHandeler.setFormatter(formatter) # 파일 메시지 포멧 설정
    # streamHandler.setFormatter(formatter) # 콘솔 메시지 포멧 설정

    log_obj.addHandler(fileHandeler) # log_obj handler에 파일 출력 방식 추가
    # log_obj.addHandler(streamHandler) # log_obj handler에 파일 콘솔 방식 추가

    return log_obj

log = logger()

# 아래 코드를 기록하고 싶은 곳에 함께 설정
log.debug('debug')
log.info('info')
log.warning('warning')
log.error('error')
log.critical('critical')

print('---')

# 아래와 같이 사용합니다.
def f():
    try:
        x = 1 / 0
    except Exception as e:
        print(e)
        log.error(f'{e} error')

f()
# Out:
# DEBUG:log_name:debug
# INFO:log_name:info
# WARNING:log_name:warning
# ERROR:log_name:error
# CRITICAL:log_name:critical
# ERROR:log_name:division by zero error
# ---
# division by zero

# %%
import logging.handlers

def logger():
    log_obj = logging.getLogger("log_name") # log name으로 log 객체 생성
    log_obj.setLevel(logging.ERROR) # 어디부터 기록할지 설정

    fileHandeler = logging.FileHandler(filename="./test.txt") # 파일로 기록
    # streamHandler = logging.StreamHandler() # 콘솔에 출력

    fileHandeler.setLevel(logging.ERROR) # 파일 기록 레벨 설정
    # streamHandler.setLevel(logging.DEBUG) # 콘솔 기록 레벨 설정

    formatter = logging.Formatter("%(name)s, %(asctime)s, %(levelname)s, %(message)s") #포멧 생성

    fileHandeler.setFormatter(formatter) # 파일 메시지 포멧 설정
    # streamHandler.setFormatter(formatter) # 콘솔 메시지 포멧 설정

    log_obj.addHandler(fileHandeler) # log_obj handler에 파일 출력 방식 추가
    # log_obj.addHandler(streamHandler) # log_obj handler에 파일 콘솔 방식 추가

    return log_obj

log = logger()

# 아래 코드를 기록하고 싶은 곳에 함께 설정
log.debug('debug')
log.info('info')
log.warning('warning')
log.error('error')
log.critical('critical')

print('---')

# 아래와 같이 사용합니다.
def f():
    try:
        x = 1 / 0
    except Exception as e:
        print(e)
        log.error(f'{e} error')

f()
# Out:
# ERROR:log_name:error
# CRITICAL:log_name:critical
# ERROR:log_name:division by zero error
# ---
# division by zero

# %% [markdown]
# ## 문제풀이

# %%
# 문제1(라운지 쓰레드)
# 두 수를 나누는 함수 div(a, b)가 있었을 때
# b에 0이 입력되면 예외처리를 하여 정상작동이 되는 함수로 작성을 해주세요.

def div(a, b):
    #정수, 실수 외 다른값을 입력시 출력
    if not (isinstance(a, int) or isinstance(a, float)) or not (isinstance(b, int) or isinstance(b, float)):
        print('정수, 실수를 입력하세요.')
        return
    try:
        return f'{a} / {b} = {a/b}'
    except:
        return '0으로 나눌 수 없습니다!'

print(div(5, 0.1))
print(div(11, 0))
# Out:
# 5 / 0.1 = 50.0
# 0으로 나눌 수 없습니다!

# %%
# 문제2(class 쓰레드)
# 하나의 숫자에 제곱근을 구하는 함수 sqrt_number(num)이 있었을 때
# 자체 예외 NegativeNumberError를 정의하세요. 이 예외는 음수가 입력될 때 발생하도록 합니다.
# 사용자로부터 숫자를 입력 받아 그 숫자의 제곱근을 반환하는 함수를 작성하세요.
# 입력된 숫자가 음수이면 NegativeNumberError를 발생시키고
# "음수의 제곱근은 계산할 수 없습니다."라는 메시지를 출력하세요.
class NegativeNumberError(Exception):
    def __init__(self):
        super().__init__('음수의 제곱근은 계산할 수 없습니다.')

def sqrt_number(num):

    if num < 0:
        raise NegativeNumberError()
    print(num**2)

sqrt_number(456)
# Out:
# 207936

# %%
# 문제3(class 쓰레드)
# 사용자로부터 인덱스 값을 입력 받아서 리스트 ["apple", "banana", "cherry"]에서
# 해당 인덱스의 값을 출력하는 함수를 작성하세요.
# 사용자가 범위를 벗어난 인덱스를 입력하면 "리스트의 범위를 벗어났습니다."라는 메시지를 출력하세요.

fruit = ["apple", "banana", "cherry"]
class OutOfList(Exception):
    def __init__(self):
        super().__init__('리스트의 범위를 벗어났습니다.')

def choice():

    try:
        index = int(input())
    except:
        print('정수를 입력해주세요.')
        return

    if len(fruit) < index:
        raise OutOfList

    print(fruit[index-1])

choice()
# Out:
# 1
# apple
